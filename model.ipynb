# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('laptop_data.csv')
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.sample()
# Out:
#      Unnamed: 0 Company  TypeName  Inches             ScreenResolution  \
# 549         549  Lenovo  Notebook    15.6  IPS Panel Full HD 1920x1080
#
#                             Cpu  Ram     Memory                    Gpu  \
# 549  Intel Core i7 7500U 2.7GHz  8GB  512GB SSD  Intel HD Graphics 620
#
#           OpSys  Weight     Price
# 549  Windows 10  1.99kg  92121.12

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.head(6)
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 5           5    Acer   Notebook    15.6                            1366x768
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
# 5     AMD A9-Series 9420 3GHz   4GB            500GB HDD
#
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
sns.displot(df['TypeName'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.displot(df['Inches'],kde=True,color='red')
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu  Ram     Memory                           Gpu  OpSys  \
# 0  Intel Core i5 2.3GHz  8GB  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight       Price
# 0  1.37kg  71378.6832

# %%
sns.displot(df['Price'],color='purple',kde=True)

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu  Ram     Memory                           Gpu  OpSys  \
# 0  Intel Core i5 2.3GHz  8GB  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight       Price
# 0  1.37kg  71378.6832

# %%
#df['Company'].value_counts().plot(kind='bar')

fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(10,5))
ax[0].bar(df['Company'],df['Price'])
ax[0].set_xticklabels(df['Company'],rotation='vertical')



ax[1].pie(df['Company'].value_counts(),autopct='%1.2f%%')
fig.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_39620\2855751898.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(df['Company'],rotation='vertical')
# C:\Users\Acer\AppData\Local\Temp\ipykernel_39620\2855751898.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
df['TypeName'].value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.barplot(x=df['Company'],y=df['Price'],color='g')
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu  Ram     Memory                           Gpu  OpSys  \
# 0  Intel Core i5 2.3GHz  8GB  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight       Price
# 0  1.37kg  71378.6832

# %%
df['Ram'].value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
from ydata_profiling import ProfileReport

# %%
#profile = ProfileReport(df, title='laptop_analyse')
#profile.to_file('laptop_analyse.html') ## save file or report
#profile.to_notebook_iframe() ## for open within jupyter notebook

# %%
df.drop_duplicates()
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1269    Asus            Notebook    15.6
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1269                                    1366x768
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df.shape
# Out:
# (1303, 11)

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df['Weight'] = df['Weight'].str.replace('kg','')
df['Ram'] = df['Ram'].str.replace('GB','')

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
df['Ram'] =  df['Ram'].astype('int32')
df['Weight']= df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
#df['Ips'] = df['ScreenResolution'].apply(lambda x: 1 if 'ips' in x.lower() else 0)


df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'],color='yellow')
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['X_res'] = df['X_res'].astype('int32')
df['Y_res'] = df['Y_res'].astype('int32')

# %%
df['ppi'] = ((df['X_res']**2) + (df['Y_res']**2) **0.5/df['Inches']).astype('float')

# %%
df.select_dtypes(include=[np.number]).corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Ips            0.252208
# Touchscreen    0.191226
# X_res          0.556529
# Y_res          0.552809
# ppi            0.515115
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution','Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Ips  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832    1            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232    0            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000    0            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360    1            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080    1            0
#
#             ppi
# 0  6.553720e+06
# ...

# %%
df['CpuName'] =df['Cpu'].apply(lambda x:" ".join (x.split()[0:3]))
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Ips  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832    1            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232    0            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000    0            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360    1            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080    1            0
#
#             ppi        CpuName
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text

    elif text.split()[0] == 'Intel':
        return 'Other intel processors'
    else:
        return 'AMd Processors'

# %%
df['Cpu_brand'] = df['CpuName'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Ips  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832    1            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232    0            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000    0            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360    1            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080    1            0
#
#             ppi        CpuName      Cpu_brand
# ...

# %%
df['Cpu_brand'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Cpu_brand'>

# %%
sns.barplot(x=df['Cpu_brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# Step 1: Clean and prepare the 'Memory' column
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')

# Step 2: Split the 'Memory' column into two parts
new = df["Memory"].str.split("+", n=1, expand=True)

# Step 3: Clean and process the first part
df["first"] = new[0].str.strip()

# Step 4: Clean and process the second part
df["second"] = new[1]

# Step 5: Identify the type of storage in the first part
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Step 6: Remove non-numeric characters from 'first'
df['first'] = df['first'].str.replace(r'\D', '', regex=True)
df['first'] = df['first'].replace('', '0')  # Replace empty strings with '0'

# Step 7: Handle the second part
df["second"].fillna("0", inplace=True)
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Step 8: Remove non-numeric characters from 'second'
df['second'] = df['second'].str.replace(r'\D', '', regex=True)
df['second'] = df['second'].replace('', '0')  # Replace empty strings with '0'

# Step 9: Convert 'first' and 'second' to integers
df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

# Step 10: Create the HDD, SSD, Hybrid, and Flash_Storage columns based on 'first' and 'second'
df["HDD"] = (df["first"] * df["Layer1HDD"] + df["second"] * df["Layer2HDD"])
df["SSD"] = (df["first"] * df["Layer1SSD"] + df["second"] * df["Layer2SSD"])
df["Hybrid"] = (df["first"] * df["Layer1Hybrid"] + df["second"] * df["Layer2Hybrid"])
df["Flash_Storage"] = (df["first"] * df["Layer1Flash_Storage"] + df["second"] * df["Layer2Flash_Storage"])

# Step 11: Drop unnecessary columns
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
                 'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
                 'Layer2Flash_Storage'], inplace=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\Acer\AppData\Local\Temp\ipykernel_39620\1103715720.py:2: SyntaxWarning: invalid escape sequence '\.'
#   df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
# C:\Users\Acer\AppData\Local\Temp\ipykernel_39620\1103715720.py:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["second"].fillna("0", inplace=True)

# %%
df
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1300  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1301      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
# 1302    Asus            Notebook  Intel Celeron Dual Core N3050 1.6GHz    4
#
# ...

# %%
df.select_dtypes(include=np.number).corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Ips              0.252208
# Touchscreen      0.191226
# ppi              0.515115
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
columns = ['Memory','Flash_Storage','Hybrid']

df.drop(columns=columns,inplace=True)

# %%
df.drop(columns=['Cpu'],inplace=True)

# %%
df
# Out:
#      Company            TypeName  Ram                           Gpu  \
# 0      Apple           Ultrabook    8  Intel Iris Plus Graphics 640
# 1      Apple           Ultrabook    8        Intel HD Graphics 6000
# 2         HP            Notebook    8         Intel HD Graphics 620
# 3      Apple           Ultrabook   16            AMD Radeon Pro 455
# 4      Apple           Ultrabook    8  Intel Iris Plus Graphics 650
# ...      ...                 ...  ...                           ...
# 1298  Lenovo  2 in 1 Convertible    4         Intel HD Graphics 520
# 1299  Lenovo  2 in 1 Convertible   16         Intel HD Graphics 520
# 1300  Lenovo            Notebook    2             Intel HD Graphics
# 1301      HP            Notebook    6            AMD Radeon R5 M330
# 1302    Asus            Notebook    4             Intel HD Graphics
#
#            OpSys  Weight        Price  Ips  Touchscreen           ppi  \
# 0          macOS    1.37   71378.6832    1            0  6.553720e+06
# ...

# %%
df['Gpu_Brand'] = df['Gpu'].apply(lambda x: x.split()[0])

# %%
df_copy = df.copy()

# %%
df_copy.to_csv('df_copy.csv', index=False)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Ips  Touchscreen           ppi        CpuName      Cpu_brand  \
# 0   71378.6832    1            0  6.553720e+06  Intel Core i5  Intel Core i5
# 1   47895.5232    0            0  2.073668e+06  Intel Core i5  Intel Core i5
# 2   30636.0000    0            0  3.686469e+06  Intel Core i5  Intel Core i5
# 3  135195.3360    1            0  8.294517e+06  Intel Core i7  Intel Core i7
# 4   96095.8080    1            0  6.553720e+06  Intel Core i5  Intel Core i5
#
#    HDD  SSD Gpu_Brand
# 0    0  128     Intel
# 1    0    0     Intel
# ...

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df['OpSys'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='OpSys'>

# %%
sns.barplot(x= df['OpSys'],y=df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == "Windows 10" or inp == "Windows 7" or inp == "Windows 10 S":
        return 'Windows'
    elif inp == "macOS" or inp == "Mac OS X":
        return 'MacOS'
    else:
        return 'Other/No OS/Linux'

# %%
df['OS'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Ips  Touchscreen  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832    1            0
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232    0            0
# 2      HP   Notebook    8  No OS    1.86   30636.0000    0            0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360    1            0
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080    1            0
#
#             ppi        CpuName      Cpu_brand  HDD  SSD Gpu_Brand  \
# 0  6.553720e+06  Intel Core i5  Intel Core i5    0  128     Intel
# 1  2.073668e+06  Intel Core i5  Intel Core i5    0    0     Intel
# 2  3.686469e+06  Intel Core i5  Intel Core i5    0  256     Intel
# 3  8.294517e+06  Intel Core i7  Intel Core i7    0  512       AMD
# 4  6.553720e+06  Intel Core i5  Intel Core i5    0  256     Intel
#
#                   OS
# 0              MacOS
# 1              MacOS
# 2  Other/No OS/Linux
# 3              MacOS
# 4              MacOS

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.displot(x=df['Weight'],kde=True)
plt.show()

# %%
df.select_dtypes(include=np.number).corr()['Price']
#df.select_dtypes(include=np.number).corr()['Price']
# Out:
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Ips            0.252208
# Touchscreen    0.191226
# ppi            0.515115
# HDD           -0.096441
# SSD            0.670799
# Name: Price, dtype: float64

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=[float, int])

# Calculate the correlation matrix
corr_matrix = numeric_df.corr()
print(corr_matrix)
# Out:
#                   Ram    Weight     Price       Ips  Touchscreen       ppi  \
# Ram          1.000000  0.383874  0.743007  0.206623     0.116984  0.398826
# Weight       0.383874  1.000000  0.210370  0.016967    -0.294620 -0.034267
# Price        0.743007  0.210370  1.000000  0.252208     0.191226  0.515115
# Ips          0.206623  0.016967  0.252208  1.000000     0.150512  0.240612
# Touchscreen  0.116984 -0.294620  0.191226  0.150512     1.000000  0.351123
# ppi          0.398826 -0.034267  0.515115  0.240612     0.351123  1.000000
# HDD          0.096288  0.514491 -0.096441 -0.094461    -0.209733 -0.109672
# SSD          0.603634 -0.062742  0.670799  0.223795     0.255092  0.488012
#
#                   HDD       SSD
# Ram          0.096288  0.603634
# Weight       0.514491 -0.062742
# Price       -0.096441  0.670799
# Ips         -0.094461  0.223795
# Touchscreen -0.209733  0.255092
# ppi         -0.109672  0.488012
# HDD          1.000000 -0.399896
# ...

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(corr_matrix, annot=True, cmap="Purples")
plt.show()

# %%
sns.displot(x=np.log(df['Price']),kde=True,color='Purple') ## applying log tranformation to price column
plt.show()

# %%
X = df.drop(columns=['Price'])
Y = np.log(df['Price'])

# %%
X.head()
# Out:
#   Company   TypeName  Ram  Weight  Ips  Touchscreen           ppi  \
# 0   Apple  Ultrabook    8    1.37    1            0  6.553720e+06
# 1   Apple  Ultrabook    8    1.34    0            0  2.073668e+06
# 2      HP   Notebook    8    1.86    0            0  3.686469e+06
# 3   Apple  Ultrabook   16    1.83    1            0  8.294517e+06
# 4   Apple  Ultrabook    8    1.37    1            0  6.553720e+06
#
#          CpuName      Cpu_brand  HDD  SSD Gpu_Brand                 OS
# 0  Intel Core i5  Intel Core i5    0  128     Intel              MacOS
# 1  Intel Core i5  Intel Core i5    0    0     Intel              MacOS
# 2  Intel Core i5  Intel Core i5    0  256     Intel  Other/No OS/Linux
# 3  Intel Core i7  Intel Core i7    0  512       AMD              MacOS
# 4  Intel Core i5  Intel Core i5    0  256     Intel              MacOS

# %%
X.drop(columns=['Cpu_brand'],inplace=True)

# %%
X.shape
# Out:
# (1303, 12)

# %%
Y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1303, dtype: float64

# %%
from sklearn.model_selection import train_test_split 

X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.15,random_state=2)

# %% [markdown]
# ### Importing neccessory lib and functions

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error


from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
# !pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.8/124.9 MB 6.7 MB/s eta 0:00:19
#    - -------------------------------------- 5.8/124.9 MB 20.8 MB/s eta 0:00:06
#    ---- ----------------------------------- 15.2/124.9 MB 30.9 MB/s eta 0:00:04
#    -------- ------------------------------- 25.4/124.9 MB 35.8 MB/s eta 0:00:03
#    -------- ------------------------------- 27.3/124.9 MB 31.4 MB/s eta 0:00:04
#    --------- ------------------------------ 29.4/124.9 MB 26.2 MB/s eta 0:00:04
#    --------- ------------------------------ 29.6/124.9 MB 24.4 MB/s eta 0:00:04
#    --------- ------------------------------ 29.6/124.9 MB 24.4 MB/s eta 0:00:04
#    --------- ------------------------------ 30.1/124.9 MB 17.4 MB/s eta 0:00:06
#    --------- ------------------------------ 31.2/124.9 MB 15.6 MB/s eta 0:00:07
#    ---------- ----------------------------- 33.6/124.9 MB 15.2 MB/s eta 0:00:07
# ...

# %% [markdown]
# ### Linear Regression

# %%
X_train.shape
# Out:
# (1107, 12)

# %%
step_1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,7,10,11])]
                           ,remainder='passthrough')
step_2 = LinearRegression()

pipe = Pipeline([
    ('step1',step_1),
    ('step2',step_2)
    
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8423395440861706
# MAE 0.19599320276416446
# c:\Users\Acer\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### Ridge regression

# %%
step_1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,7,10,11])]
                           ,remainder='passthrough')

step_2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step_1),
    ('step2',step_2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8210839805990555
# MAE 0.20954944181410892
# c:\Users\Acer\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### Lasso Regression

# %%
step_1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,7,10,11])
],remainder='passthrough')

step_2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step_1),
    ('step2',step_2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8196095197182087
# MAE 0.21155286925119807
# c:\Users\Acer\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### KNN

# %%
step_1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,7,10,11])
],remainder='passthrough')

step_2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step_1),
    ('step2',step_2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7922746534296583
# MAE 0.2048567228742641
# c:\Users\Acer\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### Decision Tree

# %%
step_1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,7,10,11])
],remainder='passthrough')

step_2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step_1),
    ('step2',step_2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8270655530146687
# MAE 0.1976437417049674
# c:\Users\Acer\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### SVM

# %%
step_1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,7,10,11])
],remainder='passthrough')

step_2 = SVR(C=1,kernel='rbf',epsilon=0.2)

pipe = Pipeline([
    ('step1',step_1),
    ('step2',step_2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.4001686780612361
# MAE 0.3804264514171104
# c:\Users\Acer\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### Random Forest

# %%
step_1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,7,10,11])
],remainder='passthrough')

step_2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)


pipe = Pipeline([
    ('step1',step_1),
    ('step2',step_2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8857547032649518
# MAE 0.16091376302801916
# c:\Users\Acer\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### Extras

# %%
step_1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,7,10,11])
],remainder='passthrough')

step_2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=None,
                              max_features=0.75,
                              max_depth=15)


pipe = Pipeline([
    ('step1',step_1),
    ('step2',step_2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8656239059839068
# MAE 0.16313958343007823
# c:\Users\Acer\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### Adaboost

# %%
step_1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,7,10,11])
],remainder='passthrough')

                                                
step_2 = AdaBoostRegressor(n_estimators=100,learning_rate=1.0)


pipe = Pipeline([
    ('step1',step_1),
    ('step2',step_2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8090082247102847
# MAE 0.2184558908294934
# c:\Users\Acer\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### XgBoost

# %%
step_1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,7,10,11])
],remainder='passthrough')

step_2 = XGBRegressor(n_estimators=100,max_depth=5,learning_rate=0.5)
                              


pipe = Pipeline([
    ('step1',step_1),
    ('step2',step_2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8920203307503338
# MAE 0.1557834094722519
# c:\Users\Acer\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### Voting regressor

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step_1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,7,10,11])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=None,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=None,max_features=0.75,max_depth=10)

step_2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe = Pipeline([
    ('step1',step_1),
    ('step2',step_2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.889104079430219
# MAE 0.15774104881348308
# c:\Users\Acer\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### stacking

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step_1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,7,10,11])
],remainder='passthrough')

estimators =[
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=None,max_features=0.75,max_depth=15)),
    ('gbdt', GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))

]
step_2 = StackingRegressor(estimators=estimators,final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step_1),
    ('step2',step_2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8774939377928033
# MAE 0.16834752707844486
# c:\Users\Acer\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:242: UserWarning: Found unknown categories in columns [2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Ips  Touchscreen  \
# 0      Apple           Ultrabook    8    1.37   71378.6832    1            0
# 1      Apple           Ultrabook    8    1.34   47895.5232    0            0
# 2         HP            Notebook    8    1.86   30636.0000    0            0
# 3      Apple           Ultrabook   16    1.83  135195.3360    1            0
# 4      Apple           Ultrabook    8    1.37   96095.8080    1            0
# ...      ...                 ...  ...     ...          ...  ...          ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400    1            1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200    1            1
# 1300  Lenovo            Notebook    2    1.50   12201.1200    0            0
# 1301      HP            Notebook    6    2.19   40705.9200    0            0
# 1302    Asus            Notebook    4    2.20   19660.3200    0            0
#
# ...

# %% [markdown]
# ### Extracing model

# %%
import pickle

pickle.dump(df,open('data.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
print(df.columns)
# Out:
# Index(['Company', 'TypeName', 'Ram', 'Weight', 'Price', 'Ips', 'Touchscreen',
#        'ppi', 'CpuName', 'Cpu_brand', 'HDD', 'SSD', 'Gpu_Brand', 'OS'],
#       dtype='object')
